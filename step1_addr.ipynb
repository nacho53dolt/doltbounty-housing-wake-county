# %%
import pandas as pd
import json, glob

with open(glob.glob('*addr*.geojson')[0]) as fp:
    txt = fp.read()
    txt = '[' + txt.strip().replace('\n', ',\n') + ']'
    data = json.loads(txt)

for i in range(len(data)):
    data[i].update(data[i]['properties'])

# %%
df = pd.DataFrame(data)

df['latitude'] = df.geometry.apply(lambda x: x['coordinates'][1])
df['longitude'] = df.geometry.apply(lambda x: x['coordinates'][0])
df = df.drop(columns=['properties', 'geometry', 'hash'])

df.to_csv('nc_wake_addrlist.csv', index=False)
df
# Out:
#            type number           street unit      city district region  \
# 0       Feature   7634     OLD US 1 HWY       NEW HILL
# 1       Feature   5217     OLD US 1 HWY       NEW HILL
# 2       Feature   5137        DAISEY ST       NEW HILL
# 3       Feature   6921  BEAVER CREEK RD       NEW HILL
# 4       Feature   5216     OLD US 1 HWY       NEW HILL
# ...         ...    ...              ...  ...       ...      ...    ...
# 480186  Feature  10401        OAKLEY RD        ZEBULON
# 480187  Feature  10405        OAKLEY RD        ZEBULON
# 480188  Feature   3021     FISHERMAN LN        ZEBULON
# 480189  Feature  10417        OAKLEY RD        ZEBULON
# 480190  Feature   1786        NC 39 HWY        ZEBULON
#
#        postcode id   latitude  longitude
# 0                   35.652707 -78.977800
# 1                   35.658136 -78.977045
# 2                   35.659573 -78.976865
# 3                   35.659573 -78.976865
# 4                   35.660521 -78.977306
# ...         ... ..        ...        ...
# 480186              35.864651 -78.281481
# 480187              35.864651 -78.281481
# 480188              35.864397 -78.278819
# 480189              35.863732 -78.279345
# 480190              35.827092 -78.255823
#
# [480191 rows x 11 columns]

# %%
df.sample(15)
# Out:
#            type number             street unit           city district region  \
# 60131   Feature    117            LYLE RD             RALEIGH
# 46468   Feature   2108       CRISPLAND CT       FUQUAY VARINA
# 71978   Feature   3025  SENTINEL FERRY LN                CARY
# 269275  Feature   1003        BUCKHORN RD              GARNER
# 230081  Feature    500           ROYAL ST             RALEIGH
# 221853  Feature   5308    MACON FOREST PL             RALEIGH
# 253865  Feature   1101       HAMMERMAN DR       WILLOW SPRING
# 466688  Feature    501         PEARCE AVE         WAKE FOREST
# 115230  Feature    108      LITTLEFORD LN                CARY
# 389364  Feature   6429      EXPERTISE AVE             RALEIGH
# 71723   Feature    709           AVOCA CT                CARY
# 256802  Feature   5016       SWORDFISH DR             RALEIGH
# 17015   Feature    947      BRIAR GATE DR       HOLLY SPRINGS
# 402975  Feature    501           BAYOU CT          KNIGHTDALE
# 2016    Feature    708   HOLLY THORN TRCE       HOLLY SPRINGS
#
#        postcode id   latitude  longitude
# 60131               35.665176 -78.676310
# 46468               35.623107 -78.746116
# 71978               35.808485 -78.921901
# 269275              35.704868 -78.634521
# 230081              35.792757 -78.688663
# 221853              35.928086 -78.698729
# 253865              35.583506 -78.660222
# 466688              35.978626 -78.504695
# 115230              35.785974 -78.852321
# 389364              35.860700 -78.532727
# 71723               35.799364 -78.922945
# 256802              35.638654 -78.644659
# 17015               35.600745 -78.821046
# 402975              35.790665 -78.499732
# 2016                35.638136 -78.872156
